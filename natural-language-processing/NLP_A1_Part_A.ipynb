# %% [markdown]
# ## Configuration

# %%
# Import spaCy
import spacy

from pathlib import Path
from spacy.matcher import Matcher

# %%
# This contains the processing pipeline
# As well as language-specific rules for tokenization etc.
nlp = spacy.load('en_core_web_lg')

# %%
# Read from a text file and replace newline characters
moby_dick = Path('../Text Files/moby_dick.txt').read_text(encoding='utf8')
moby_dick = moby_dick.replace('\n', '')

ai_forecast_1 = Path('../Text Files/ai_forecast1.txt').read_text(encoding='utf8')
ai_forecast_1 = ai_forecast_1.replace('\n', '')

ai_forecast_2 = Path('../Text Files/ai_forecast2.txt').read_text(encoding='utf8')
ai_forecast_2 = ai_forecast_2.replace('\n', '')

# Import them into a Doc object
moby_dick_doc = nlp(moby_dick)
ai_forecast_1_doc = nlp(ai_forecast_1)
ai_forecast_2_doc = nlp(ai_forecast_2)

# Test
print(moby_dick_doc.text)
# Out:
# I stuffed a shirt or two into my old carpet-bag, tucked it under my arm, and started for Cape Horn and the Pacific. Quitting the good city of old Manhatto, I duly arrived in New Bedford. It was a Saturday night in December. Much was I disappointed upon learning that the little packet for Nantucket had already sailed, and that no way of reaching that place would offer, till the following Monday. As most young candidates for the pains and penalties of whaling stop at this same New Bedford, thence to embark on their voyage, it may as well be related that I, for one, had no idea of so doing. For my mind was made up to sail in no other than a Nantucket craft, because there was a fine, boisterous something about everything connected with that famous old island, which amazingly pleased me. Besides though New Bedford has of late been gradually monopolising the business of whaling, and though in this matter poor old Nantucket is now much behind her, yet Nantucket was her great original—the Tyre of this Carthage;—the place where the first dead American whale was stranded.

# %% [markdown]
# # Print out the POS and the grammatical structure of the sentences

# %% [markdown]
# Note: I intentionally only printed the first two sentences for both, in order to not clutter up the screen.
#
# If by any chance you want to see all the sentences, remove the [0:2]
#
# or
#
# you can also just do:
# ```
# for sentence in doc.sents:
# ```

# %% [markdown]
# ## AI Forecast 1

# %%
# Storing sentences
doc_sentences = [sentence for sentence in ai_forecast_1_doc.sents]

# Iterate over the sentences
for sentence in doc_sentences[0:2]:
    # These conditions are just added for prettier printing
    if sentence == doc_sentences[0]:
        print('{}\n'.format(sentence))

    else:
        print('\n\n\n{}\n'.format(sentence))

    # Iterate over the tokens
    for token in sentence:
        # Print the text, the predicted part-of-speech tag, syntactic dependencies and head text
        print(token.text, token.pos_, token.dep_, token.head.text)
# Out:
# Pune, India, Sept. 13, 2022 (GLOBE NEWSWIRE) --
#
# Pune PROPN ROOT Pune
# , PUNCT punct Pune
# India PROPN npadvmod Pune
# , PUNCT punct Pune
# Sept. PROPN npadvmod Pune
# 13 NUM nummod Sept.
# , PUNCT punct Sept.
# 2022 NUM nummod Sept.
# ( PUNCT punct Pune
# GLOBE PROPN compound NEWSWIRE
# NEWSWIRE PROPN appos Pune
# ) PUNCT punct Pune
# -- PUNCT punct Pune
#
#
#
# The global AI market size is projected to grow from USD 387.45 billion in 2022 to USD 1394.30 billion in 2029 at a CAGR of 20.1% in the forecast period.
#
# The DET det size
# global ADJ amod size
# AI PROPN compound size
# market NOUN compound size
# size NOUN nsubjpass projected
# is AUX auxpass projected
# projected VERB ROOT projected
# to PART aux grow
# grow VERB xcomp projected
# from ADP prep grow
# USD SYM pobj from
# 387.45 NUM compound billion
# billion NUM nummod USD
# in ADP prep grow
# 2022 NUM pobj in
# to ADP prep grow
# USD SYM compound billion
# 1394.30 NUM compound billion
# billion NUM pobj to
# in ADP prep grow
# 2029 NUM pobj in
# at ADP prep grow
# a DET det CAGR
# CAGR NOUN pobj at
# of ADP prep CAGR
# 20.1 NUM nummod %
# % NOUN pobj of
# in ADP prep grow
# the DET det period
# forecast NOUN compound period
# period NOUN pobj in
# . PUNCT punct projected

# %% [markdown]
# ## AI Forecast 2

# %%
# Storing sentences
doc_sentences = [sentence for sentence in ai_forecast_2_doc.sents]

# Iterate over the sentences
for sentence in doc_sentences[0:2]:
    # These conditions are just added for prettier printing
    if sentence == doc_sentences[0]:
        print('{}\n'.format(sentence))

    else:
        print('\n\n\n{}\n'.format(sentence))

    # Iterate over the tokens
    for token in sentence:
        # Print the text, the predicted part-of-speech tag, syntactic dependencies and head text
        print(token.text, token.pos_, token.dep_, token.head.text)
# Out:
# The global artificial intelligence market size was $93.5 billion in 2021.
#
# The DET det size
# global ADJ amod size
# artificial ADJ amod size
# intelligence NOUN compound market
# market NOUN compound size
# size NOUN nsubj was
# was AUX ROOT was
# $ SYM quantmod billion
# 93.5 NUM compound billion
# billion NUM attr was
# in ADP prep was
# 2021 NUM pobj in
# . PUNCT punct was
#
#
#
# And according to Grand View Research, Inc., it is projected to expand at a compound annual growth rate (CAGR) of 38.1% from 2022 to 2030.
#
# And CCONJ cc projected
# according VERB prep projected
# to ADP prep according
# Grand PROPN compound Inc.
# View PROPN compound Inc.
# Research PROPN nmod Inc.
# , PUNCT punct Inc.
# Inc. PROPN pobj to
# , PUNCT punct projected
# it PRON nsubjpass projected
# is AUX auxpass projected
# projected VERB ROOT projected
# to PART aux expand
# expand VERB xcomp projected
# at ADP prep expand
# a DET det rate
# compound ADJ nmod rate
# annual ADJ amod rate
# growth NOUN compound rate
# rate NOUN pobj at
# ( PUNCT punct rate
# CAGR NOUN appos rate
# ) PUNCT punct rate
# of ADP prep rate
# 38.1 NUM nummod %
# % NOUN pobj of
# from ADP prep expand
# 2022 NUM pobj from
# to ADP prep from
# 2030 NUM pobj to
# . PUNCT punct projected

# %% [markdown]
# # Display the named entities, their labels and label descriptions

# %% [markdown]
# ## AI Forecast 1

# %%
# Iterate over the predicted entities
for ent in ai_forecast_1_doc.ents:
    # Print the entity text , it's label and explanation
    print('Named Entity - {}\nEntity Label - {}\nEntity Label Description - {}\n\n'.format(ent.text, ent.label_, spacy.explain(ent.label_)))
# Out:
# Named Entity - Pune
# Entity Label - GPE
# Entity Label Description - Countries, cities, states
#
#
# Named Entity - India
# Entity Label - GPE
# Entity Label Description - Countries, cities, states
#
#
# Named Entity - Sept. 13, 2022
# Entity Label - DATE
# Entity Label Description - Absolute or relative dates or periods
#
#
# Named Entity - GLOBE NEWSWIRE
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - USD 387.45 billion
# Entity Label - MONEY
# Entity Label Description - Monetary values, including unit
#
#
# Named Entity - 2022
# Entity Label - DATE
# Entity Label Description - Absolute or relative dates or periods
#
#
# Named Entity - USD 1394.30 billion
# Entity Label - MONEY
# Entity Label Description - Monetary values, including unit
#
#
# Named Entity - 2029
# Entity Label - DATE
# Entity Label Description - Absolute or relative dates or periods
#
#
# Named Entity - 20.1%
# Entity Label - PERCENT
# Entity Label Description - Percentage, including "%"
#
#
# Named Entity - the next several years
# Entity Label - DATE
# Entity Label Description - Absolute or relative dates or periods
#
#
# Named Entity - Fortune Business Insights™
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Artificial Intelligence Market Forecast
# Entity Label - WORK_OF_ART
# Entity Label Description - Titles of books, songs, etc.
#
#
# Named Entity - 2022-2029
# Entity Label - DATE
# Entity Label Description - Absolute or relative dates or periods
#
#
# Named Entity - USD 328.34 billion
# Entity Label - MONEY
# Entity Label Description - Monetary values, including unit
#
#
# Named Entity - 2021
# Entity Label - DATE
# Entity Label Description - Absolute or relative dates or periods
#
#
# Named Entity - BFSI
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - healthcare
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - a Sample Copy
# Entity Label - PERSON
# Entity Label Description - People, including fictional
#
#
# Named Entity - the Research Report
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Microsoft
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - April 12, 2021
# Entity Label - DATE
# Entity Label Description - Absolute or relative dates or periods
#
#
# Named Entity - Microsoft News Center Share
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Facebook
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Twitter
# Entity Label - PRODUCT
# Entity Label Description - Objects, vehicles, foods, etc. (not services)
#
#
# Named Entity - Microsoft
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - REDMOND
# Entity Label - GPE
# Entity Label Description - Countries, cities, states
#
#
# Named Entity - Wash.
# Entity Label - GPE
# Entity Label Description - Countries, cities, states
#
#
# Named Entity - BURLINGTON
# Entity Label - GPE
# Entity Label Description - Countries, cities, states
#
#
# Named Entity - Mass.
# Entity Label - GPE
# Entity Label Description - Countries, cities, states
#
#
# Named Entity - April 12, 2021
# Entity Label - DATE
# Entity Label Description - Absolute or relative dates or periods
#
#
# Named Entity - Microsoft Corp
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Nuance Communications, Inc.
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - NUAN
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - today
# Entity Label - DATE
# Entity Label Description - Absolute or relative dates or periods
#
#
# Named Entity - Microsoft
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Nuance
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - 56.00
# Entity Label - MONEY
# Entity Label Description - Monetary values, including unit
#
#
# Named Entity - 23%
# Entity Label - PERCENT
# Entity Label Description - Percentage, including "%"
#
#
# Named Entity - Friday, April 9
# Entity Label - DATE
# Entity Label Description - Absolute or relative dates or periods
#
#
# Named Entity - $19.7 billion
# Entity Label - MONEY
# Entity Label Description - Monetary values, including unit
#
#
# Named Entity - Nuance
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - decades
# Entity Label - DATE
# Entity Label Description - Absolute or relative dates or periods
#
#
# Named Entity - Mark Benjamin
# Entity Label - PERSON
# Entity Label Description - People, including fictional
#
#
# Named Entity - Nuance
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Scott Guthrie
# Entity Label - PERSON
# Entity Label Description - People, including fictional
#
#
# Named Entity - Cloud & AI
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Microsoft
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Microsoft
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - the Microsoft Cloud
# Entity Label - PRODUCT
# Entity Label Description - Objects, vehicles, foods, etc. (not services)
#
#
# Named Entity - Healthcare
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - 2020
# Entity Label - DATE
# Entity Label Description - Absolute or relative dates or periods
#
#
# Named Entity - Today
# Entity Label - DATE
# Entity Label Description - Absolute or relative dates or periods
#
#
# Named Entity - Microsoft
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Nuance
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Dragon Medical One
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - PowerScribe
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - One
# Entity Label - CARDINAL
# Entity Label Description - Numerals that do not fall under another type
#
#
# Named Entity - Microsoft Azure
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Nuance
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Electronic Health Records
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - more than 55%
# Entity Label - PERCENT
# Entity Label Description - Percentage, including "%"
#
#
# Named Entity - 75%
# Entity Label - PERCENT
# Entity Label Description - Percentage, including "%"
#
#
# Named Entity - U.S.
# Entity Label - GPE
# Entity Label Description - Countries, cities, states
#
#
# Named Entity - 77%
# Entity Label - PERCENT
# Entity Label Description - Percentage, including "%"
#
#
# Named Entity - U.S.
# Entity Label - GPE
# Entity Label Description - Countries, cities, states
#
#
# Named Entity - Nuance
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Healthcare
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - 37%
# Entity Label - PERCENT
# Entity Label Description - Percentage, including "%"
#
#
# Named Entity - Nuance
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - fiscal year 2020
# Entity Label - DATE
# Entity Label Description - Absolute or relative dates or periods
#
#
# Named Entity - September 2020
# Entity Label - DATE
# Entity Label Description - Absolute or relative dates or periods
#
#
# Named Entity - Microsoft
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Nuance
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - 2019
# Entity Label - DATE
# Entity Label Description - Absolute or relative dates or periods
#
#
# Named Entity - the Microsoft Cloud
# Entity Label - PRODUCT
# Entity Label Description - Objects, vehicles, foods, etc. (not services)
#
#
# Named Entity - Healthcare
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Nuance
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Nuance
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Microsoft
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Microsoft
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Microsoft
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - TAM
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - TAM
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - healthcare
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - nearly $500 billion
# Entity Label - MONEY
# Entity Label Description - Monetary values, including unit
#
#
# Named Entity - Microsoft
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - healthcare
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Satya Nadella
# Entity Label - PERSON
# Entity Label Description - People, including fictional
#
#
# Named Entity - Microsoft
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Microsoft Cloud
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Healthcare
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Nuance
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Interactive Voice Response
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Microsoft
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Dynamics 365
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - the past three years
# Entity Label - DATE
# Entity Label Description - Absolute or relative dates or periods
#
#
# Named Entity - Nuance
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Mark Benjamin
# Entity Label - PERSON
# Entity Label Description - People, including fictional
#
#
# Named Entity - Nuance
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Microsoft
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - the Boards of Directors of both Nuance
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Microsoft
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Nuance
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Microsoft
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Nuance
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Microsoft
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Intelligent Cloud
# Entity Label - PRODUCT
# Entity Label Description - Objects, vehicles, foods, etc. (not services)
#
#
# Named Entity - Microsoft
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - less than 1 percent
# Entity Label - PERCENT
# Entity Label Description - Percentage, including "%"
#
#
# Named Entity - fiscal year 2022
# Entity Label - DATE
# Entity Label Description - Absolute or relative dates or periods
#
#
# Named Entity - fiscal year 2023
# Entity Label - DATE
# Entity Label Description - Absolute or relative dates or periods
#
#
# Named Entity - Nadella, Benjamin, Guthrie
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Microsoft
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Amy Hood
# Entity Label - PERSON
# Entity Label Description - People, including fictional
#
#
# Named Entity - April 12, 2021
# Entity Label - DATE
# Entity Label Description - Absolute or relative dates or periods
#
#
# Named Entity - 8 a.m.
# Entity Label - TIME
# Entity Label Description - Times smaller than a day
#
#
# Named Entity - 201
# Entity Label - CARDINAL
# Entity Label Description - Numerals that do not fall under another type
#
#
# Named Entity - 689-8023
# Entity Label - CARDINAL
# Entity Label Description - Numerals that do not fall under another type
#
#
# Named Entity - U.S.
# Entity Label - GPE
# Entity Label Description - Countries, cities, states
#
#
# Named Entity - Goldman Sachs & Co. LLC
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Microsoft
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Simpson Thacher & Bartlett LLP
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Evercore
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Nuance
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Paul, Weiss, Rifkind, Wharton & Garrison LLP
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Microsoft Microsoft
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Nuance Communications, Inc.
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - NUAN
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - 77 percent
# Entity Label - PERCENT
# Entity Label Description - Percentage, including "%"
#
#
# Named Entity - U.S.
# Entity Label - GPE
# Entity Label Description - Countries, cities, states
#
#
# Named Entity - 85 percent
# Entity Label - PERCENT
# Entity Label Description - Percentage, including "%"
#
#
# Named Entity - 100
# Entity Label - CARDINAL
# Entity Label Description - Numerals that do not fall under another type
#
#
# Named Entity - Microsoft Media Relations
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - WE Communications
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - 425
# Entity Label - CARDINAL
# Entity Label Description - Numerals that do not fall under another type
#
#
# Named Entity - Microsoft
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - the Microsoft News Center
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Microsoft
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Rapid Response Team
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Nuance
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Nuance Communications, Inc.
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - the United States
# Entity Label - GPE
# Entity Label Description - Countries, cities, states

# %% [markdown]
# ## AI Forecast 2

# %%
# Iterate over the predicted entities
for ent in ai_forecast_2_doc.ents:
    # Print the entity text , it's label and explanation
    print('Named Entity - {}\nEntity Label - {}\nEntity Label Description - {}\n\n'.format(ent.text, ent.label_, spacy.explain(ent.label_)))
# Out:
# Named Entity - $93.5 billion
# Entity Label - MONEY
# Entity Label Description - Monetary values, including unit
#
#
# Named Entity - 2021
# Entity Label - DATE
# Entity Label Description - Absolute or relative dates or periods
#
#
# Named Entity - Grand View Research, Inc.
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - annual
# Entity Label - DATE
# Entity Label Description - Absolute or relative dates or periods
#
#
# Named Entity - 38.1%
# Entity Label - PERCENT
# Entity Label Description - Percentage, including "%"
#
#
# Named Entity - 2022
# Entity Label - DATE
# Entity Label Description - Absolute or relative dates or periods
#
#
# Named Entity - 2030
# Entity Label - DATE
# Entity Label Description - Absolute or relative dates or periods
#
#
# Named Entity - healthcare
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - around 66%
# Entity Label - PERCENT
# Entity Label Description - Percentage, including "%"
#
#
# Named Entity - 2016
# Entity Label - DATE
# Entity Label Description - Absolute or relative dates or periods
#
#
# Named Entity - AI
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - life sciences
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - eCommerce
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - NVIDIA Corporation
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - NVDA
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Intel Corporation
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Alphabet Inc.
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Amazon Web Services Inc.
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - AMZN
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Artificial Intelligence Market by Technology
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - night
# Entity Label - TIME
# Entity Label Description - Times smaller than a day
#
#
# Named Entity - life sciences
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - BFSI
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - one
# Entity Label - CARDINAL
# Entity Label Description - Numerals that do not fall under another type
#
#
# Named Entity - 2020
# Entity Label - DATE
# Entity Label Description - Absolute or relative dates or periods
#
#
# Named Entity - CoverGirl
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - the next few years
# Entity Label - DATE
# Entity Label Description - Absolute or relative dates or periods
#
#
# Named Entity - PMFD
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Global Al Market
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Erik Brynjolfsson
# Entity Label - PERSON
# Entity Label Description - People, including fictional
#
#
# Named Entity - Stanford Institute for Human-Centered AI
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - HAI
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - the Stanford Digital Economy Lab
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - annual
# Entity Label - DATE
# Entity Label Description - Absolute or relative dates or periods
#
#
# Named Entity - AI
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Stanford
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - HAI
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - 2020
# Entity Label - DATE
# Entity Label Description - Absolute or relative dates or periods
#
#
# Named Entity - Brynjolfsson
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - healthcare
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - AI.
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Artificial Intelligence Systems
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Tortoise Intelligence
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - 115%
# Entity Label - PERCENT
# Entity Label Description - Percentage, including "%"
#
#
# Named Entity - 2020
# Entity Label - DATE
# Entity Label Description - Absolute or relative dates or periods
#
#
# Named Entity - year-over-year
# Entity Label - DATE
# Entity Label Description - Absolute or relative dates or periods
#
#
# Named Entity - at least two decades
# Entity Label - DATE
# Entity Label Description - Absolute or relative dates or periods
#
#
# Named Entity - China
# Entity Label - GPE
# Entity Label Description - Countries, cities, states
#
#
# Named Entity - The European Union
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - EU
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Horizon 2020
# Entity Label - PRODUCT
# Entity Label Description - Objects, vehicles, foods, etc. (not services)
#
#
# Named Entity - €1 billion
# Entity Label - MONEY
# Entity Label Description - Monetary values, including unit
#
#
# Named Entity - 2021
# Entity Label - DATE
# Entity Label Description - Absolute or relative dates or periods
#
#
# Named Entity - North America
# Entity Label - LOC
# Entity Label Description - Non-GPE locations, mountain ranges, bodies of water
#
#
# Named Entity - more than 42%
# Entity Label - PERCENT
# Entity Label Description - Percentage, including "%"
#
#
# Named Entity - Trump
# Entity Label - PERSON
# Entity Label Description - People, including fictional
#
#
# Named Entity - American
# Entity Label - NORP
# Entity Label Description - Nationalities or religious or political groups
#
#
# Named Entity - February 2019
# Entity Label - DATE
# Entity Label Description - Absolute or relative dates or periods
#
#
# Named Entity - North America
# Entity Label - LOC
# Entity Label Description - Non-GPE locations, mountain ranges, bodies of water
#
#
# Named Entity - the coming years
# Entity Label - DATE
# Entity Label Description - Absolute or relative dates or periods
#
#
# Named Entity - North America
# Entity Label - LOC
# Entity Label Description - Non-GPE locations, mountain ranges, bodies of water
#
#
# Named Entity - U.S.
# Entity Label - GPE
# Entity Label Description - Countries, cities, states
#
#
# Named Entity - Canada
# Entity Label - GPE
# Entity Label Description - Countries, cities, states
#
#
# Named Entity - Mexico
# Entity Label - GPE
# Entity Label Description - Countries, cities, states
#
#
# Named Entity - North America
# Entity Label - LOC
# Entity Label Description - Non-GPE locations, mountain ranges, bodies of water
#
#
# Named Entity - Asia
# Entity Label - LOC
# Entity Label Description - Non-GPE locations, mountain ranges, bodies of water
#
#
# Named Entity - Pacific
# Entity Label - LOC
# Entity Label Description - Non-GPE locations, mountain ranges, bodies of water
#
#
# Named Entity - the next few years
# Entity Label - DATE
# Entity Label Description - Absolute or relative dates or periods
#
#
# Named Entity - Baidu, Inc.
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.
#
#
# Named Entity - Chinese
# Entity Label - NORP
# Entity Label Description - Nationalities or religious or political groups
#
#
# Named Entity - April 2018
# Entity Label - DATE
# Entity Label Description - Absolute or relative dates or periods
#
#
# Named Entity - healthcare
# Entity Label - ORG
# Entity Label Description - Companies, agencies, institutions, etc.

# %% [markdown]
# # Use the matcher to look up 'Artificial Intelligence' in the text
#
# Documentation: [https://spacy.io/api/matcher](https://spacy.io/api/matcher)

# %%
# Initialize the matcher with the shared vocab
matcher = Matcher(nlp.vocab)

# Add the pattern to the matcher
pattern = [{"LOWER": "artificial"}, {"LOWER": "intelligence"}]
matcher.add("ARTIFICIAL_INTELLIGENCE_PATTERN", [pattern])

# Call the matcher on the doc
matches = matcher(ai_forecast_2_doc)

# Iterate over the matches
for match_id, start, end in matches:
    string_id = nlp.vocab.strings[match_id]  # Get string representation
    # Get the matched span
    matched_span = ai_forecast_2_doc[start:end]
    print('Match ID: {}\nMatched Pattern: {}\nStart: {}\nEnd: {}\nMatched Text: {}\n\n'.format(match_id, string_id, start, end, matched_span.text))
# Out:
# Match ID: 8058983868262941017
# Matched Pattern: ARTIFICIAL_INTELLIGENCE_PATTERN
# Start: 2
# End: 4
# Matched Text: artificial intelligence
#
#
# Match ID: 8058983868262941017
# Matched Pattern: ARTIFICIAL_INTELLIGENCE_PATTERN
# Start: 95
# End: 97
# Matched Text: Artificial intelligence
#
#
# Match ID: 8058983868262941017
# Matched Pattern: ARTIFICIAL_INTELLIGENCE_PATTERN
# Start: 159
# End: 161
# Matched Text: artificial intelligence
#
#
# Match ID: 8058983868262941017
# Matched Pattern: ARTIFICIAL_INTELLIGENCE_PATTERN
# Start: 359
# End: 361
# Matched Text: Artificial Intelligence
#
#
# Match ID: 8058983868262941017
# Matched Pattern: ARTIFICIAL_INTELLIGENCE_PATTERN
# Start: 447
# End: 449
# Matched Text: Artificial Intelligence
#
#
# Match ID: 8058983868262941017
# Matched Pattern: ARTIFICIAL_INTELLIGENCE_PATTERN
# Start: 458
# End: 460
# Matched Text: artificial intelligence
#
#
# Match ID: 8058983868262941017
# Matched Pattern: ARTIFICIAL_INTELLIGENCE_PATTERN
# Start: 627
# End: 629
# Matched Text: Artificial Intelligence
#
#
# Match ID: 8058983868262941017
# Matched Pattern: ARTIFICIAL_INTELLIGENCE_PATTERN
# Start: 775
# End: 777
# Matched Text: artificial intelligence
#
#
# Match ID: 8058983868262941017
# Matched Pattern: ARTIFICIAL_INTELLIGENCE_PATTERN
# Start: 1220
# End: 1222
# Matched Text: Artificial Intelligence
#
#
# Match ID: 8058983868262941017
# Matched Pattern: ARTIFICIAL_INTELLIGENCE_PATTERN
# Start: 1346
# End: 1348
# Matched Text: artificial intelligence
#
#
# Match ID: 8058983868262941017
# Matched Pattern: ARTIFICIAL_INTELLIGENCE_PATTERN
# Start: 1423
# End: 1425
# Matched Text: artificial intelligence
#
#
# Match ID: 8058983868262941017
# Matched Pattern: ARTIFICIAL_INTELLIGENCE_PATTERN
# Start: 1574
# End: 1576
# Matched Text: artificial intelligence

# %% [markdown]
# # Construct a matcher that looks for the word 'AI' followed by a verb
#
# Since it wasn't mentioned for which document, I only did this for the Key Market Insights text.
# The other one didn't have any results either way...

# %%
# Initialize the matcher with the shared vocab
matcher = Matcher(nlp.vocab)

# Add the pattern to the matcher
pattern = [{"LOWER": "ai"}, {"POS": "VERB"}]
matcher.add("AI_FOLLOWED_BY_VERB_PATTERN", [pattern])

# Call the matcher on the doc
matches = matcher(ai_forecast_2_doc)

# Iterate over the matches
for match_id, start, end in matches:
    string_id = nlp.vocab.strings[match_id]  # Get string representation
    # Get the matched span
    matched_span = ai_forecast_2_doc[start:end]
    print('Match ID: {}\nMatched Pattern: {}\nStart: {}\nEnd: {}\nMatched Text: {}\n\n'.format(match_id, string_id, start, end, matched_span.text))
# Out:
# Match ID: 17616057253289433113
# Matched Pattern: AI_FOLLOWED_BY_VERB_PATTERN
# Start: 1054
# End: 1056
# Matched Text: AI grew

# %% [markdown]
# # Construct a matcher to find all numbers followed by a percent sign (%)

# %% [markdown]
# ## AI Forecast 1

# %%
# Initialize the matcher with the shared vocab
matcher = Matcher(nlp.vocab)

# Add the pattern to the matcher
pattern = [{"POS": "NUM"}, {"TEXT": "%"}]
matcher.add("NUMBER_FOLLOWED_BY_PERCENT_SIGN_PATTERN", [pattern])

# Call the matcher on the doc
matches = matcher(ai_forecast_1_doc)

# Iterate over the matches
for match_id, start, end in matches:
    string_id = nlp.vocab.strings[match_id]  # Get string representation
    # Get the matched span
    matched_span = ai_forecast_1_doc[start:end]
    print('Match ID: {}\nMatched Pattern: {}\nStart: {}\nEnd: {}\nMatched Text: {}\n\n'.format(match_id, string_id, start, end, matched_span.text))
# Out:
# Match ID: 4462332722968326931
# Matched Pattern: NUMBER_FOLLOWED_BY_PERCENT_SIGN_PATTERN
# Start: 38
# End: 40
# Matched Text: 20.1%
#
#
# Match ID: 4462332722968326931
# Matched Pattern: NUMBER_FOLLOWED_BY_PERCENT_SIGN_PATTERN
# Start: 275
# End: 277
# Matched Text: 23%
#
#
# Match ID: 4462332722968326931
# Matched Pattern: NUMBER_FOLLOWED_BY_PERCENT_SIGN_PATTERN
# Start: 531
# End: 533
# Matched Text: 55%
#
#
# Match ID: 4462332722968326931
# Matched Pattern: NUMBER_FOLLOWED_BY_PERCENT_SIGN_PATTERN
# Start: 536
# End: 538
# Matched Text: 75%
#
#
# Match ID: 4462332722968326931
# Matched Pattern: NUMBER_FOLLOWED_BY_PERCENT_SIGN_PATTERN
# Start: 547
# End: 549
# Matched Text: 77%
#
#
# Match ID: 4462332722968326931
# Matched Pattern: NUMBER_FOLLOWED_BY_PERCENT_SIGN_PATTERN
# Start: 559
# End: 561
# Matched Text: 37%

# %% [markdown]
# ## AI Forecast 2

# %%
# Initialize the matcher with the shared vocab
matcher = Matcher(nlp.vocab)

# Add the pattern to the matcher
pattern = [{"POS": "NUM"}, {"TEXT": "%"}]
matcher.add("NUMBER_FOLLOWED_BY_PERCENT_SIGN_PATTERN", [pattern])

# Call the matcher on the doc
matches = matcher(ai_forecast_2_doc)

# Iterate over the matches
for match_id, start, end in matches:
    string_id = nlp.vocab.strings[match_id]  # Get string representation
    # Get the matched span
    matched_span = ai_forecast_2_doc[start:end]
    print('Match ID: {}\nMatched Pattern: {}\nStart: {}\nEnd: {}\nMatched Text: {}\n\n'.format(match_id, string_id, start, end, matched_span.text))
# Out:
# Match ID: 4462332722968326931
# Matched Pattern: NUMBER_FOLLOWED_BY_PERCENT_SIGN_PATTERN
# Start: 37
# End: 39
# Matched Text: 38.1%
#
#
# Match ID: 4462332722968326931
# Matched Pattern: NUMBER_FOLLOWED_BY_PERCENT_SIGN_PATTERN
# Start: 196
# End: 198
# Matched Text: 66%
#
#
# Match ID: 4462332722968326931
# Matched Pattern: NUMBER_FOLLOWED_BY_PERCENT_SIGN_PATTERN
# Start: 1236
# End: 1238
# Matched Text: 115%
#
#
# Match ID: 4462332722968326931
# Matched Pattern: NUMBER_FOLLOWED_BY_PERCENT_SIGN_PATTERN
# Start: 1378
# End: 1380
# Matched Text: 42%

# %% [markdown]
# # Construct a matcher to look for companies names

# %% [markdown]
# ## AI Forecast 1

# %%
# Initialize the matcher with the shared vocab
matcher = Matcher(nlp.vocab)

# Add the pattern to the matcher
pattern = [{"ENT_TYPE": "ORG"}]
matcher.add("COMPANY_NAME_PATTERN", [pattern])

# Call the matcher on the doc
matches = matcher(ai_forecast_1_doc)

# Iterate over the matches
for match_id, start, end in matches:
    string_id = nlp.vocab.strings[match_id]  # Get string representation
    # Get the matched span
    matched_span = ai_forecast_1_doc[start:end]
    print('Match ID: {}\nMatched Pattern: {}\nStart: {}\nEnd: {}\nMatched Text: {}\n\n'.format(match_id, string_id, start, end, matched_span.text))
# Out:
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 9
# End: 10
# Matched Text: GLOBE
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 10
# End: 11
# Matched Text: NEWSWIRE
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 66
# End: 67
# Matched Text: Fortune
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 67
# End: 68
# Matched Text: Business
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 68
# End: 69
# Matched Text: Insights
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 69
# End: 70
# Matched Text: ™
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 122
# End: 123
# Matched Text: BFSI
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 124
# End: 125
# Matched Text: healthcare
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 150
# End: 151
# Matched Text: the
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 151
# End: 152
# Matched Text: Research
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 152
# End: 153
# Matched Text: Report
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 155
# End: 156
# Matched Text: Microsoft
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 172
# End: 173
# Matched Text: Microsoft
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 173
# End: 174
# Matched Text: News
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 174
# End: 175
# Matched Text: Center
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 175
# End: 176
# Matched Text: Share
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 177
# End: 178
# Matched Text: Facebook
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 217
# End: 218
# Matched Text: Microsoft
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 235
# End: 236
# Matched Text: Microsoft
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 236
# End: 237
# Matched Text: Corp
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 243
# End: 244
# Matched Text: Nuance
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 244
# End: 245
# Matched Text: Communications
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 245
# End: 246
# Matched Text: ,
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 246
# End: 247
# Matched Text: Inc.
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 250
# End: 251
# Matched Text: NUAN
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 263
# End: 264
# Matched Text: Microsoft
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 266
# End: 267
# Matched Text: Nuance
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 304
# End: 305
# Matched Text: Nuance
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 334
# End: 335
# Matched Text: Nuance
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 345
# End: 346
# Matched Text: Cloud
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 346
# End: 347
# Matched Text: &
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 347
# End: 348
# Matched Text: AI
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 349
# End: 350
# Matched Text: Microsoft
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 361
# End: 362
# Matched Text: Microsoft
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 394
# End: 395
# Matched Text: Healthcare
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 425
# End: 426
# Matched Text: Microsoft
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 455
# End: 456
# Matched Text: Nuance
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 464
# End: 465
# Matched Text: Dragon
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 465
# End: 466
# Matched Text: Medical
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 466
# End: 467
# Matched Text: One
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 468
# End: 469
# Matched Text: PowerScribe
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 483
# End: 484
# Matched Text: Microsoft
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 484
# End: 485
# Matched Text: Azure
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 486
# End: 487
# Matched Text: Nuance
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 500
# End: 501
# Matched Text: Electronic
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 501
# End: 502
# Matched Text: Health
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 502
# End: 503
# Matched Text: Records
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 553
# End: 554
# Matched Text: Nuance
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 555
# End: 556
# Matched Text: Healthcare
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 568
# End: 569
# Matched Text: Nuance
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 579
# End: 580
# Matched Text: Microsoft
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 583
# End: 584
# Matched Text: Nuance
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 605
# End: 606
# Matched Text: Healthcare
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 607
# End: 608
# Matched Text: Nuance
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 617
# End: 618
# Matched Text: Nuance
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 627
# End: 628
# Matched Text: Microsoft
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 645
# End: 646
# Matched Text: Microsoft
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 653
# End: 654
# Matched Text: Microsoft
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 659
# End: 660
# Matched Text: TAM
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 671
# End: 672
# Matched Text: TAM
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 673
# End: 674
# Matched Text: healthcare
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 682
# End: 683
# Matched Text: Microsoft
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 716
# End: 717
# Matched Text: healthcare
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 741
# End: 742
# Matched Text: Microsoft
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 796
# End: 797
# Matched Text: Microsoft
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 797
# End: 798
# Matched Text: Cloud
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 799
# End: 800
# Matched Text: Healthcare
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 807
# End: 808
# Matched Text: Nuance
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 816
# End: 817
# Matched Text: Interactive
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 817
# End: 818
# Matched Text: Voice
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 818
# End: 819
# Matched Text: Response
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 851
# End: 852
# Matched Text: Microsoft
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 861
# End: 862
# Matched Text: Dynamics
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 862
# End: 863
# Matched Text: 365
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 882
# End: 883
# Matched Text: Nuance
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 918
# End: 919
# Matched Text: Nuance
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 962
# End: 963
# Matched Text: Microsoft
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1026
# End: 1027
# Matched Text: the
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1027
# End: 1028
# Matched Text: Boards
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1028
# End: 1029
# Matched Text: of
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1029
# End: 1030
# Matched Text: Directors
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1030
# End: 1031
# Matched Text: of
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1031
# End: 1032
# Matched Text: both
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1032
# End: 1033
# Matched Text: Nuance
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1034
# End: 1035
# Matched Text: Microsoft
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1055
# End: 1056
# Matched Text: Nuance
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1075
# End: 1076
# Matched Text: Microsoft
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1077
# End: 1078
# Matched Text: Nuance
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1086
# End: 1087
# Matched Text: Microsoft
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1092
# End: 1093
# Matched Text: Microsoft
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1168
# End: 1169
# Matched Text: Nadella
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1169
# End: 1170
# Matched Text: ,
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1170
# End: 1171
# Matched Text: Benjamin
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1171
# End: 1172
# Matched Text: ,
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1172
# End: 1173
# Matched Text: Guthrie
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1174
# End: 1175
# Matched Text: Microsoft
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1253
# End: 1254
# Matched Text: Goldman
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1254
# End: 1255
# Matched Text: Sachs
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1255
# End: 1256
# Matched Text: &
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1256
# End: 1257
# Matched Text: Co.
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1257
# End: 1258
# Matched Text: LLC
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1265
# End: 1266
# Matched Text: Microsoft
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1268
# End: 1269
# Matched Text: Simpson
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1269
# End: 1270
# Matched Text: Thacher
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1270
# End: 1271
# Matched Text: &
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1271
# End: 1272
# Matched Text: Bartlett
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1272
# End: 1273
# Matched Text: LLP
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1280
# End: 1281
# Matched Text: Evercore
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1288
# End: 1289
# Matched Text: Nuance
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1291
# End: 1292
# Matched Text: Paul
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1292
# End: 1293
# Matched Text: ,
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1293
# End: 1294
# Matched Text: Weiss
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1294
# End: 1295
# Matched Text: ,
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1295
# End: 1296
# Matched Text: Rifkind
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1296
# End: 1297
# Matched Text: ,
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1297
# End: 1298
# Matched Text: Wharton
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1298
# End: 1299
# Matched Text: &
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1299
# End: 1300
# Matched Text: Garrison
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1300
# End: 1301
# Matched Text: LLP
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1309
# End: 1310
# Matched Text: Microsoft
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1310
# End: 1311
# Matched Text: Microsoft
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1351
# End: 1352
# Matched Text: Nuance
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1352
# End: 1353
# Matched Text: Communications
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1353
# End: 1354
# Matched Text: ,
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1354
# End: 1355
# Matched Text: Inc.
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1360
# End: 1361
# Matched Text: NUAN
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1418
# End: 1419
# Matched Text: Microsoft
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1419
# End: 1420
# Matched Text: Media
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1420
# End: 1421
# Matched Text: Relations
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1422
# End: 1423
# Matched Text: WE
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1423
# End: 1424
# Matched Text: Communications
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1445
# End: 1446
# Matched Text: Microsoft
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1449
# End: 1450
# Matched Text: the
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1450
# End: 1451
# Matched Text: Microsoft
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1451
# End: 1452
# Matched Text: News
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1452
# End: 1453
# Matched Text: Center
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1483
# End: 1484
# Matched Text: Microsoft
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1485
# End: 1486
# Matched Text: Rapid
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1486
# End: 1487
# Matched Text: Response
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1487
# End: 1488
# Matched Text: Team
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1502
# End: 1503
# Matched Text: Nuance
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1510
# End: 1511
# Matched Text: Nuance
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1511
# End: 1512
# Matched Text: Communications
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1512
# End: 1513
# Matched Text: ,
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1513
# End: 1514
# Matched Text: Inc.

# %% [markdown]
# ## AI Forecast 2

# %%
# Initialize the matcher with the shared vocab
matcher = Matcher(nlp.vocab)

# Add the pattern to the matcher
pattern = [{"ENT_TYPE": "ORG"}]
matcher.add("COMPANY_NAME_PATTERN", [pattern])

# Call the matcher on the doc
matches = matcher(ai_forecast_2_doc)

# Iterate over the matches
for match_id, start, end in matches:
    string_id = nlp.vocab.strings[match_id]  # Get string representation
    # Get the matched span
    matched_span = ai_forecast_2_doc[start:end]
    print('Match ID: {}\nMatched Pattern: {}\nStart: {}\nEnd: {}\nMatched Text: {}\n\n'.format(match_id, string_id, start, end, matched_span.text))
# Out:
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 16
# End: 17
# Matched Text: Grand
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 17
# End: 18
# Matched Text: View
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 18
# End: 19
# Matched Text: Research
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 19
# End: 20
# Matched Text: ,
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 20
# End: 21
# Matched Text: Inc.
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 110
# End: 111
# Matched Text: healthcare
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 206
# End: 207
# Matched Text: AI
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 212
# End: 213
# Matched Text: life
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 213
# End: 214
# Matched Text: sciences
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 240
# End: 241
# Matched Text: eCommerce
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 296
# End: 297
# Matched Text: NVIDIA
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 297
# End: 298
# Matched Text: Corporation
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 299
# End: 300
# Matched Text: NVDA
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 302
# End: 303
# Matched Text: Intel
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 303
# End: 304
# Matched Text: Corporation
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 308
# End: 309
# Matched Text: Alphabet
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 309
# End: 310
# Matched Text: Inc.
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 315
# End: 316
# Matched Text: Amazon
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 316
# End: 317
# Matched Text: Web
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 317
# End: 318
# Matched Text: Services
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 318
# End: 319
# Matched Text: Inc.
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 320
# End: 321
# Matched Text: AMZN
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 447
# End: 448
# Matched Text: Artificial
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 448
# End: 449
# Matched Text: Intelligence
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 449
# End: 450
# Matched Text: Market
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 450
# End: 451
# Matched Text: by
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 451
# End: 452
# Matched Text: Technology
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 650
# End: 651
# Matched Text: life
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 651
# End: 652
# Matched Text: sciences
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 657
# End: 658
# Matched Text: BFSI
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 737
# End: 738
# Matched Text: CoverGirl
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 893
# End: 894
# Matched Text: PMFD
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 920
# End: 921
# Matched Text: Global
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 921
# End: 922
# Matched Text: Al
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 922
# End: 923
# Matched Text: Market
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 989
# End: 990
# Matched Text: Stanford
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 990
# End: 991
# Matched Text: Institute
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 991
# End: 992
# Matched Text: for
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 992
# End: 993
# Matched Text: Human
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 993
# End: 994
# Matched Text: -
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 994
# End: 995
# Matched Text: Centered
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 995
# End: 996
# Matched Text: AI
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 997
# End: 998
# Matched Text: HAI
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1002
# End: 1003
# Matched Text: the
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1003
# End: 1004
# Matched Text: Stanford
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1004
# End: 1005
# Matched Text: Digital
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1005
# End: 1006
# Matched Text: Economy
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1006
# End: 1007
# Matched Text: Lab
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1036
# End: 1037
# Matched Text: AI
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1044
# End: 1045
# Matched Text: Stanford
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1045
# End: 1046
# Matched Text: HAI
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1107
# End: 1108
# Matched Text: Brynjolfsson
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1200
# End: 1201
# Matched Text: healthcare
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1215
# End: 1216
# Matched Text: AI
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1216
# End: 1217
# Matched Text: .
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1220
# End: 1221
# Matched Text: Artificial
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1221
# End: 1222
# Matched Text: Intelligence
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1222
# End: 1223
# Matched Text: Systems
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1225
# End: 1226
# Matched Text: Tortoise
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1226
# End: 1227
# Matched Text: Intelligence
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1313
# End: 1314
# Matched Text: The
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1314
# End: 1315
# Matched Text: European
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1315
# End: 1316
# Matched Text: Union
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1317
# End: 1318
# Matched Text: EU
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1580
# End: 1581
# Matched Text: Baidu
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1581
# End: 1582
# Matched Text: ,
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1582
# End: 1583
# Matched Text: Inc.
#
#
# Match ID: 11620291018188914089
# Matched Pattern: COMPANY_NAME_PATTERN
# Start: 1662
# End: 1663
# Matched Text: healthcare

# %% [markdown]
# # Where do you find these matches ?

# %% [markdown]
# For each match, I print out the Start and End token, hopefully that answers the question...

# %%
print(ai_forecast_2_doc[16:21])
# Out:
# Grand View Research, Inc.
